# %% [markdown]
# ## Dataset Visualization
# # test split= 10% and cross validation performed

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVC  ## Import SVC
from sklearn import svm
from sklearn.metrics import f1_score
from pandas.plotting import scatter_matrix
import sklearn.linear_model as skl_lm
from sklearn.preprocessing import StandardScaler
from sqlalchemy import create_engine
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.naive_bayes import GaussianNB
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import make_pipeline
# %matplotlib inline  
from pandas.plotting import scatter_matrix
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 

accent_dataset = pd.read_csv("accent-mfcc-data-1.csv")
#collect datatset

# %%
accent_dataset.head(330)  
##look at the rows sprcified in head() using the DataFrame’s head()
# Out:
#     language         X1        X2        X3         X4        X5         X6  \
# 0         ES   7.071476 -6.512900  7.650800  11.150783 -7.657312  12.484021
# 1         ES  10.982967 -5.157445  3.952060  11.529381 -7.638047  12.136098
# 2         ES   7.827108 -5.477472  7.816257   9.187592 -7.172511  11.715299
# 3         ES   6.744083 -5.688920  6.546789   9.000183 -6.924963  11.710766
# 4         ES   5.836843 -5.326557  7.472265   8.847440 -6.773244  12.677218
# ..       ...        ...       ...       ...        ...       ...        ...
# 324       US  -0.525273 -3.868338  3.548304   1.496249  3.490753   5.849887
# 325       US  -2.094001 -1.073113  1.217397  -0.550790  2.666547   7.449942
# 326       US   2.116909 -4.441482  5.350392   3.675396  2.715876   3.682670
# 327       US   0.299616  0.324844  3.299919   2.044040  3.634828   6.693840
# 328       US   3.214254 -3.135152  1.122691   4.712444  5.926518   6.915566
#
#             X7         X8         X9        X10       X11       X12
# 0   -11.709772   3.426596   1.462715  -2.812753  0.866538 -5.244274
# 1   -12.036247   3.491943   0.595441  -4.508811  2.332147 -6.221857
# 2   -13.847214   4.574075  -1.687559  -7.204041 -0.011847 -6.463144
# 3   -12.374388   6.169879  -0.544747  -6.019237  1.358559 -6.356441
# 4   -12.315061   4.416344   0.193500  -3.644812  2.151239 -6.816310
# ..         ...        ...        ...        ...       ...       ...
# 324  -7.747027   9.738836 -11.754543   7.129909  0.209947 -1.946914
# 325  -6.418064  10.907098 -11.134323   6.728373  2.461446 -0.026113
# 326  -4.500850  11.798565 -12.031005   7.566142 -0.606010 -2.245129
# 327  -5.676224  12.000518 -11.912901   4.664406  1.197789 -2.230275
# 328  -5.799727  10.858532 -11.659845  10.605734  0.349482 -5.983281
#
# [329 rows x 13 columns]

# %%
#******** dataset cleaning *************
accent_dataset_clean = accent_dataset.dropna() #drop rows which have nan data  
print("Sheet-1")
accent_dataset_clean.describe()  ##The describe() method shows a summary of the numerical attributes
# Out:
# Sheet-1
#                X1          X2          X3          X4          X5          X6  \
# count  329.000000  329.000000  329.000000  329.000000  329.000000  329.000000
# mean     5.645227   -4.270814    2.635319    7.200207   -5.648733    9.810236
# std      5.105302    3.514350    3.635323    4.310095    4.596180    3.624654
# min     -6.067831  -14.972962   -6.186583   -8.844231  -15.656596   -3.528964
# 25%      2.065603   -6.515764    0.137042    4.700874   -8.417684    8.643563
# 50%      4.954206   -4.252512    2.029268    7.804680   -6.786670   10.379330
# 75%      9.793648   -1.560250    4.178026   10.129165   -4.463308   11.784360
# max     17.749851    3.570765   17.066487   16.178942    7.912809   21.445837
#
#                X7          X8          X9         X10         X11         X12
# count  329.000000  329.000000  329.000000  329.000000  329.000000  329.000000
# mean    -9.408053    5.117328   -1.229432   -2.362288    2.430833   -3.980415
# std      2.484117    2.650608    3.634849    5.042034    3.478467    2.985879
# min    -15.365665   -2.873862  -15.510974  -11.429178  -13.664104  -13.724103
# 25%    -11.120860    3.482167   -1.749082   -5.083522    1.197789   -5.941409
# 50%     -9.710399    4.843103   -0.389970   -3.323147    3.169703   -4.374334
# 75%     -7.989370    6.588931    0.779993   -1.506037    4.673452   -2.191658
# max     -0.424033   13.846083    4.789989   16.326455    9.166066    5.259430

# %%
accent_dataset_clean.info()
##The info() method is useful to get a quick description of the data, in particular the-
##-total number of rows, and each attribute’s type and number of non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 329 entries, 0 to 328
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   language  329 non-null    object
#  1   X1        329 non-null    float64
#  2   X2        329 non-null    float64
#  3   X3        329 non-null    float64
#  4   X4        329 non-null    float64
#  5   X5        329 non-null    float64
#  6   X6        329 non-null    float64
#  7   X7        329 non-null    float64
#  8   X8        329 non-null    float64
#  9   X9        329 non-null    float64
#  10  X10       329 non-null    float64
#  11  X11       329 non-null    float64
#  12  X12       329 non-null    float64
# dtypes: float64(12), object(1)
# memory usage: 36.0+ KB

# %% [markdown]
# # --- Data Visualization ---

# %%
# *****histogram*****
accent_dataset_clean.hist(bins = 50, figsize = (10,10)) #hist for histogram, bin is number of vertical bars in graph
plt.show()

# %%
#******* plot scatter matrix ********
from pandas.plotting import scatter_matrix
scatter_matrix(accent_dataset_clean, figsize=(20, 10))
# Out:
# array([[<AxesSubplot:xlabel='X1', ylabel='X1'>,
#         <AxesSubplot:xlabel='X2', ylabel='X1'>,
#         <AxesSubplot:xlabel='X3', ylabel='X1'>,
#         <AxesSubplot:xlabel='X4', ylabel='X1'>,
#         <AxesSubplot:xlabel='X5', ylabel='X1'>,
#         <AxesSubplot:xlabel='X6', ylabel='X1'>,
#         <AxesSubplot:xlabel='X7', ylabel='X1'>,
#         <AxesSubplot:xlabel='X8', ylabel='X1'>,
#         <AxesSubplot:xlabel='X9', ylabel='X1'>,
#         <AxesSubplot:xlabel='X10', ylabel='X1'>,
#         <AxesSubplot:xlabel='X11', ylabel='X1'>,
#         <AxesSubplot:xlabel='X12', ylabel='X1'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X2'>,
#         <AxesSubplot:xlabel='X2', ylabel='X2'>,
#         <AxesSubplot:xlabel='X3', ylabel='X2'>,
#         <AxesSubplot:xlabel='X4', ylabel='X2'>,
#         <AxesSubplot:xlabel='X5', ylabel='X2'>,
#         <AxesSubplot:xlabel='X6', ylabel='X2'>,
#         <AxesSubplot:xlabel='X7', ylabel='X2'>,
#         <AxesSubplot:xlabel='X8', ylabel='X2'>,
#         <AxesSubplot:xlabel='X9', ylabel='X2'>,
#         <AxesSubplot:xlabel='X10', ylabel='X2'>,
#         <AxesSubplot:xlabel='X11', ylabel='X2'>,
#         <AxesSubplot:xlabel='X12', ylabel='X2'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X3'>,
#         <AxesSubplot:xlabel='X2', ylabel='X3'>,
#         <AxesSubplot:xlabel='X3', ylabel='X3'>,
#         <AxesSubplot:xlabel='X4', ylabel='X3'>,
#         <AxesSubplot:xlabel='X5', ylabel='X3'>,
#         <AxesSubplot:xlabel='X6', ylabel='X3'>,
#         <AxesSubplot:xlabel='X7', ylabel='X3'>,
#         <AxesSubplot:xlabel='X8', ylabel='X3'>,
#         <AxesSubplot:xlabel='X9', ylabel='X3'>,
#         <AxesSubplot:xlabel='X10', ylabel='X3'>,
#         <AxesSubplot:xlabel='X11', ylabel='X3'>,
#         <AxesSubplot:xlabel='X12', ylabel='X3'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X4'>,
#         <AxesSubplot:xlabel='X2', ylabel='X4'>,
#         <AxesSubplot:xlabel='X3', ylabel='X4'>,
#         <AxesSubplot:xlabel='X4', ylabel='X4'>,
#         <AxesSubplot:xlabel='X5', ylabel='X4'>,
#         <AxesSubplot:xlabel='X6', ylabel='X4'>,
#         <AxesSubplot:xlabel='X7', ylabel='X4'>,
#         <AxesSubplot:xlabel='X8', ylabel='X4'>,
#         <AxesSubplot:xlabel='X9', ylabel='X4'>,
#         <AxesSubplot:xlabel='X10', ylabel='X4'>,
#         <AxesSubplot:xlabel='X11', ylabel='X4'>,
#         <AxesSubplot:xlabel='X12', ylabel='X4'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X5'>,
#         <AxesSubplot:xlabel='X2', ylabel='X5'>,
#         <AxesSubplot:xlabel='X3', ylabel='X5'>,
#         <AxesSubplot:xlabel='X4', ylabel='X5'>,
#         <AxesSubplot:xlabel='X5', ylabel='X5'>,
#         <AxesSubplot:xlabel='X6', ylabel='X5'>,
#         <AxesSubplot:xlabel='X7', ylabel='X5'>,
#         <AxesSubplot:xlabel='X8', ylabel='X5'>,
#         <AxesSubplot:xlabel='X9', ylabel='X5'>,
#         <AxesSubplot:xlabel='X10', ylabel='X5'>,
#         <AxesSubplot:xlabel='X11', ylabel='X5'>,
#         <AxesSubplot:xlabel='X12', ylabel='X5'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X6'>,
#         <AxesSubplot:xlabel='X2', ylabel='X6'>,
#         <AxesSubplot:xlabel='X3', ylabel='X6'>,
#         <AxesSubplot:xlabel='X4', ylabel='X6'>,
#         <AxesSubplot:xlabel='X5', ylabel='X6'>,
#         <AxesSubplot:xlabel='X6', ylabel='X6'>,
#         <AxesSubplot:xlabel='X7', ylabel='X6'>,
#         <AxesSubplot:xlabel='X8', ylabel='X6'>,
#         <AxesSubplot:xlabel='X9', ylabel='X6'>,
#         <AxesSubplot:xlabel='X10', ylabel='X6'>,
#         <AxesSubplot:xlabel='X11', ylabel='X6'>,
#         <AxesSubplot:xlabel='X12', ylabel='X6'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X7'>,
#         <AxesSubplot:xlabel='X2', ylabel='X7'>,
#         <AxesSubplot:xlabel='X3', ylabel='X7'>,
#         <AxesSubplot:xlabel='X4', ylabel='X7'>,
#         <AxesSubplot:xlabel='X5', ylabel='X7'>,
#         <AxesSubplot:xlabel='X6', ylabel='X7'>,
#         <AxesSubplot:xlabel='X7', ylabel='X7'>,
#         <AxesSubplot:xlabel='X8', ylabel='X7'>,
#         <AxesSubplot:xlabel='X9', ylabel='X7'>,
#         <AxesSubplot:xlabel='X10', ylabel='X7'>,
#         <AxesSubplot:xlabel='X11', ylabel='X7'>,
#         <AxesSubplot:xlabel='X12', ylabel='X7'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X8'>,
#         <AxesSubplot:xlabel='X2', ylabel='X8'>,
#         <AxesSubplot:xlabel='X3', ylabel='X8'>,
#         <AxesSubplot:xlabel='X4', ylabel='X8'>,
#         <AxesSubplot:xlabel='X5', ylabel='X8'>,
#         <AxesSubplot:xlabel='X6', ylabel='X8'>,
#         <AxesSubplot:xlabel='X7', ylabel='X8'>,
#         <AxesSubplot:xlabel='X8', ylabel='X8'>,
#         <AxesSubplot:xlabel='X9', ylabel='X8'>,
#         <AxesSubplot:xlabel='X10', ylabel='X8'>,
#         <AxesSubplot:xlabel='X11', ylabel='X8'>,
#         <AxesSubplot:xlabel='X12', ylabel='X8'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X9'>,
#         <AxesSubplot:xlabel='X2', ylabel='X9'>,
#         <AxesSubplot:xlabel='X3', ylabel='X9'>,
#         <AxesSubplot:xlabel='X4', ylabel='X9'>,
#         <AxesSubplot:xlabel='X5', ylabel='X9'>,
#         <AxesSubplot:xlabel='X6', ylabel='X9'>,
#         <AxesSubplot:xlabel='X7', ylabel='X9'>,
#         <AxesSubplot:xlabel='X8', ylabel='X9'>,
#         <AxesSubplot:xlabel='X9', ylabel='X9'>,
#         <AxesSubplot:xlabel='X10', ylabel='X9'>,
#         <AxesSubplot:xlabel='X11', ylabel='X9'>,
#         <AxesSubplot:xlabel='X12', ylabel='X9'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X10'>,
#         <AxesSubplot:xlabel='X2', ylabel='X10'>,
#         <AxesSubplot:xlabel='X3', ylabel='X10'>,
#         <AxesSubplot:xlabel='X4', ylabel='X10'>,
#         <AxesSubplot:xlabel='X5', ylabel='X10'>,
#         <AxesSubplot:xlabel='X6', ylabel='X10'>,
#         <AxesSubplot:xlabel='X7', ylabel='X10'>,
#         <AxesSubplot:xlabel='X8', ylabel='X10'>,
#         <AxesSubplot:xlabel='X9', ylabel='X10'>,
#         <AxesSubplot:xlabel='X10', ylabel='X10'>,
#         <AxesSubplot:xlabel='X11', ylabel='X10'>,
#         <AxesSubplot:xlabel='X12', ylabel='X10'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X11'>,
#         <AxesSubplot:xlabel='X2', ylabel='X11'>,
#         <AxesSubplot:xlabel='X3', ylabel='X11'>,
#         <AxesSubplot:xlabel='X4', ylabel='X11'>,
#         <AxesSubplot:xlabel='X5', ylabel='X11'>,
#         <AxesSubplot:xlabel='X6', ylabel='X11'>,
#         <AxesSubplot:xlabel='X7', ylabel='X11'>,
#         <AxesSubplot:xlabel='X8', ylabel='X11'>,
#         <AxesSubplot:xlabel='X9', ylabel='X11'>,
#         <AxesSubplot:xlabel='X10', ylabel='X11'>,
#         <AxesSubplot:xlabel='X11', ylabel='X11'>,
#         <AxesSubplot:xlabel='X12', ylabel='X11'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X12'>,
#         <AxesSubplot:xlabel='X2', ylabel='X12'>,
#         <AxesSubplot:xlabel='X3', ylabel='X12'>,
#         <AxesSubplot:xlabel='X4', ylabel='X12'>,
#         <AxesSubplot:xlabel='X5', ylabel='X12'>,
#         <AxesSubplot:xlabel='X6', ylabel='X12'>,
#         <AxesSubplot:xlabel='X7', ylabel='X12'>,
#         <AxesSubplot:xlabel='X8', ylabel='X12'>,
#         <AxesSubplot:xlabel='X9', ylabel='X12'>,
#         <AxesSubplot:xlabel='X10', ylabel='X12'>,
#         <AxesSubplot:xlabel='X11', ylabel='X12'>,
#         <AxesSubplot:xlabel='X12', ylabel='X12'>]], dtype=object)

# %% [markdown]
# ### Box plot

# %%
accent_dataset_clean.boxplot(column=['X1'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X2'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X3'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X4'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X5'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X6'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X7'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X8'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X9'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X10'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X11'])
# Out:
# <AxesSubplot:>

# %%
accent_dataset_clean.boxplot(column=['X12'])
# Out:
# <AxesSubplot:>

# %%
# **********correlation matrix/ heat map ********
corr = accent_dataset_clean.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f8ee1_row0_col0, #T_f8ee1_row1_col1, #T_f8ee1_row2_col2, #T_f8ee1_row3_col3, #T_f8ee1_row4_col4, #T_f8ee1_row5_col5, #T_f8ee1_row6_col6, #T_f8ee1_row7_col7, #T_f8ee1_row8_col8, #T_f8ee1_row9_col9, #T_f8ee1_row10_col10, #T_f8ee1_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f8ee1_row0_col1, #T_f8ee1_row1_col0, #T_f8ee1_row4_col8, #T_f8ee1_row5_col11, #T_f8ee1_row8_col4, #T_f8ee1_row8_col6, #T_f8ee1_row8_col7, #T_f8ee1_row8_col9, #T_f8ee1_row9_col3, #T_f8ee1_row9_col5, #T_f8ee1_row9_col8, #T_f8ee1_row9_col10, #T_f8ee1_row10_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f8ee1_row0_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_f8ee1_row0_col3, #T_f8ee1_row9_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_f8ee1_row0_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f8ee1_row0_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_f8ee1_row0_col6, #T_f8ee1_row1_col10, #T_f8ee1_row4_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f8ee1_row0_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f8ee1_row0_col8 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_f8ee1_row0_col9, #T_f8ee1_row2_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_f8ee1_row0_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f8ee1_row0_col11 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f8ee1_row1_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f8ee1_row1_col3, #T_f8ee1_row1_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f8ee1_row1_col4, #T_f8ee1_row6_col7, #T_f8ee1_row7_col6 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f8ee1_row1_col6, #T_f8ee1_row7_col10, #T_f8ee1_row11_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_f8ee1_row1_col7, #T_f8ee1_row4_col2, #T_f8ee1_row7_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_f8ee1_row1_col8, #T_f8ee1_row6_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f8ee1_row1_col9 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f8ee1_row1_col11 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_f8ee1_row2_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_f8ee1_row2_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f8ee1_row2_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_f8ee1_row2_col4 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_f8ee1_row2_col6 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_f8ee1_row2_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_f8ee1_row2_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_f8ee1_row2_col9, #T_f8ee1_row6_col11 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_f8ee1_row2_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f8ee1_row2_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f8ee1_row3_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_f8ee1_row3_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f8ee1_row3_col2, #T_f8ee1_row8_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_f8ee1_row3_col4, #T_f8ee1_row7_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f8ee1_row3_col5 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_f8ee1_row3_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f8ee1_row3_col7, #T_f8ee1_row6_col8, #T_f8ee1_row10_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_f8ee1_row3_col8 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_f8ee1_row3_col9, #T_f8ee1_row5_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_f8ee1_row3_col10, #T_f8ee1_row6_col9 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_f8ee1_row3_col11, #T_f8ee1_row4_col0, #T_f8ee1_row4_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f8ee1_row4_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f8ee1_row4_col6 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_f8ee1_row4_col7 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_f8ee1_row4_col9 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_f8ee1_row4_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_f8ee1_row4_col11, #T_f8ee1_row9_col11, #T_f8ee1_row11_col6 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_f8ee1_row5_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_f8ee1_row5_col1, #T_f8ee1_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f8ee1_row5_col2, #T_f8ee1_row11_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_f8ee1_row5_col3 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_f8ee1_row5_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_f8ee1_row5_col7, #T_f8ee1_row8_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_f8ee1_row5_col8 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_f8ee1_row5_col9, #T_f8ee1_row7_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f8ee1_row5_col10 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_f8ee1_row6_col0, #T_f8ee1_row9_col1 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f8ee1_row6_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_f8ee1_row6_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_f8ee1_row6_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f8ee1_row6_col10 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_f8ee1_row7_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_f8ee1_row7_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_f8ee1_row7_col4, #T_f8ee1_row11_col4, #T_f8ee1_row11_col9 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_f8ee1_row7_col5, #T_f8ee1_row11_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f8ee1_row7_col9, #T_f8ee1_row8_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_f8ee1_row7_col11 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_f8ee1_row8_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_f8ee1_row8_col3 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_f8ee1_row8_col5 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_f8ee1_row8_col10 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_f8ee1_row9_col0, #T_f8ee1_row11_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f8ee1_row9_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_f8ee1_row9_col4 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_f8ee1_row9_col7 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_f8ee1_row10_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_f8ee1_row10_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_f8ee1_row10_col3 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_f8ee1_row10_col5 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_f8ee1_row10_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f8ee1_row10_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_f8ee1_row10_col8 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_f8ee1_row10_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f8ee1_row10_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_f8ee1_row11_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_f8ee1_row11_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f8ee1_row11_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_f8ee1_row11_col10 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f8ee1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >X1</th>
#       <th class="col_heading level0 col1" >X2</th>
#       <th class="col_heading level0 col2" >X3</th>
#       <th class="col_heading level0 col3" >X4</th>
#       <th class="col_heading level0 col4" >X5</th>
#       <th class="col_heading level0 col5" >X6</th>
#       <th class="col_heading level0 col6" >X7</th>
#       <th class="col_heading level0 col7" >X8</th>
#       <th class="col_heading level0 col8" >X9</th>
#       <th class="col_heading level0 col9" >X10</th>
#       <th class="col_heading level0 col10"

# %%
# ****** different langauges values represted in graphical from *******
print(accent_dataset_clean.language.value_counts())
accent_dataset_clean.language.value_counts().plot(kind='bar', title='Count (Languages)');
# Out:
# US    165
# UK     45
# FR     30
# GE     30
# IT     30
# ES     29
# Name: language, dtype: int64

# %% [markdown]
# # --- Model Development ---

# %% [markdown]
# # Train data and Test Data split to 90% and 10%

# %%
accent_dataset_clean['isUS'] = [True if l == 'US' else False for l in accent_dataset_clean['language']]
df_accent = accent_dataset_clean.drop(['X4','X5','X6'], axis = 1)

# %%
X = df_accent.drop(['language', 'isUS'], axis=1)
y = df_accent['isUS']
#print(X, y)

# %%
# ****** different langauges values represted in graphical from *******
print(df_accent.isUS.value_counts())
df_accent.isUS.value_counts().plot(kind='bar', title='Count (isUS)');
# Out:
# True     165
# False    164
# Name: isUS, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=1)

# %% [markdown]
# # 1) KNN

# %%
for i in range(1,10):
        knn_clf = KNeighborsClassifier(n_jobs=-1, n_neighbors=i) 
        knn_clf.fit(X_train ,y_train)
        knn_pred_test = knn_clf.predict(X_test)
        knn_pred_X_train = knn_clf.predict(X_train)
        accuracy_score(y_test, knn_pred_test)
        print("\n Value of neighbors : ", i)
        print(classification_report(y_test, knn_pred_test, target_names = ['Not US','Is US'], digits = 7))
        print("confusion matrix for y train is : ")
        print(confusion_matrix(y_train, knn_pred_X_train))
        print("confusion matrix for y test is : ")
        print(confusion_matrix(y_test, knn_pred_test))
        print("accuracy score for training : ")
        print(accuracy_score(y_train, knn_pred_X_train))
        print("=================================================== \n")
# Out:
#  Value of neighbors :  1
#               precision    recall  f1-score   support
#
#       Not US  0.7857143 0.6875000 0.7333333        16
#        Is US  0.7368421 0.8235294 0.7777778        17
#
#     accuracy                      0.7575758        33
#    macro avg  0.7612782 0.7555147 0.7555556        33
# weighted avg  0.7605377 0.7575758 0.7562290        33
#
# confusion matrix for y train is :
# [[148   0]
#  [  0 148]]
# confusion matrix for y test is :
# [[11  5]
#  [ 3 14]]
# accuracy score for training :
# 1.0
# ===================================================
#
#
#  Value of neighbors :  2
#               precision    recall  f1-score   support
#
#       Not US  0.8125000 0.8125000 0.8125000        16
#        Is US  0.8235294 0.8235294 0.8235294        17
#
#     accuracy                      0.8181818        33
#    macro avg  0.8180147 0.8180147 0.8180147        33
# weighted avg  0.8181818 0.8181818 0.8181818        33
#
# confusion matrix for y train is :
# [[148   0]
#  [ 26 122]]
# confusion matrix for y test is :
# [[13  3]
#  [ 3 14]]
# accuracy score for training :
# 0.9121621621621622
# ===================================================
#
#
#  Value of neighbors :  3
#               precision    recall  f1-score   support
#
#       Not US  0.8666667 0.8125000 0.8387097        16
#        Is US  0.8333333 0.8823529 0.8571429        17
#
#     accuracy                      0.8484848        33
#    macro avg  0.8500000 0.8474265 0.8479263        33
# weighted avg  0.8494949 0.8484848 0.8482056        33
#
# confusion matrix for y train is :
# [[139   9]
#  [ 12 136]]
# confusion matrix for y test is :
# [[13  3]
#  [ 2 15]]
# accuracy score for training :
# 0.9290540540540541
# ===================================================
#
#
#  Value of neighbors :  4
#               precision    recall  f1-score   support
#
#       Not US  0.8888889 1.0000000 0.9411765        16
#        Is US  1.0000000 0.8823529 0.9375000        17
#
#     accuracy                      0.9393939        33
#    macro avg  0.9444444 0.9411765 0.9393382        33
# weighted avg  0.9461279 0.9393939 0.9392825        33
#
# confusion matrix for y train is :
# [[145   3]
#  [ 30 118]]
# confusion matrix for y test is :
# [[16  0]
#  [ 2 15]]
# accuracy score for training :
# 0.8885135135135135
# ===================================================
#
#
#  Value of neighbors :  5
#               precision    recall  f1-score   support
#
#       Not US  0.8823529 0.9375000 0.9090909        16
#        Is US  0.9375000 0.8823529 0.9090909        17
#
#     accuracy                      0.9090909        33
#    macro avg  0.9099265 0.9099265 0.9090909        33
# weighted avg  0.9107620 0.9090909 0.9090909        33
#
# confusion matrix for y train is :
# [[138  10]
#  [ 22 126]]
# confusion matrix for y test is :
# [[15  1]
#  [ 2 15]]
# accuracy score for training :
# 0.8918918918918919
# ===================================================
#
#
#  Value of neighbors :  6
#               precision    recall  f1-score   support
#
#       Not US  0.8888889 1.0000000 0.9411765        16
#        Is US  1.0000000 0.8823529 0.9375000        17
#
#     accuracy                      0.9393939        33
#    macro avg  0.9444444 0.9411765 0.9393382        33
# weighted avg  0.9461279 0.9393939 0.9392825        33
#
# confusion matrix for y train is :
# [[141   7]
#  [ 31 117]]
# confusion matrix for y test is :
# [[16  0]
#  [ 2 15]]
# accuracy score for training :
# 0.8716216216216216
# ===================================================
#
#
#  Value of neighbors :  7
#               precision    recall  f1-score   support
#
#       Not US  0.9375000 0.9375000 0.9375000        16
#        Is US  0.9411765 0.9411765 0.9411765        17
#
#     accuracy                      0.9393939        33
#    macro avg  0.9393382 0.9393382 0.9393382        33
# weighted avg  0.9393939 0.9393939 0.9393939        33
#
# confusion matrix for y train is :
# [[139   9]
#  [ 22 126]]
# confusion matrix for y test is :
# [[15  1]
#  [ 1 16]]
# accuracy score for training :
# 0.8952702702702703
# ===================================================
#
#
#  Value of neighbors :  8
#               precision    recall  f1-score   support
#
#       Not US  0.9411765 1.0000000 0.9696970        16
#        Is US  1.0000000 0.9411765 0.9696970        17
#
#     accuracy                      0.9696970        33
#    macro avg  0.9705882 0.9705882 0.9696970        33
# weighted avg  0.9714795 0.9696970 0.9696970        33
#
# confusion matrix for y train is :
# [[140   8]
#  [ 33 115]]
# confusion matrix for y test is :
# [[16  0]
#  [ 1 16]]
# accuracy score for training :
# 0.8614864864864865
# ===================================================
#
#
#  Value of neighbors :  9
#               precision    recall  f1-score   support
#
#       Not US  1.0000000 0.9375000 0.9677419        16
#        Is US  0.9444444 1.0000000 0.9714286        17
#
#     accuracy                      0.9696970        33
#    macro avg  0.9722222 0.9687500 0.9695853        33
# weighted avg  0.9713805 0.9696970 0.9696411        33
#
# confusion matrix for y train is :
# [[134  14]
#  [ 29 119]]
# confusion matrix for y test is :
# [[15  1]
#  [ 0 17]]
# accuracy score for training :
# 0.8547297297297297
# ===================================================

# %% [markdown]
# # Observation for KNN:
# when test data to train data ration is 1:9, the best accuracy is seen when KNN is calculated with 2,4,5 and 9 neighbors
# 0.96 accuracy with KNN=8 and 9

# %% [markdown]
# # 2) SVM:
# Note: We have tried to implement SVM by changing kernel paramter and degree paramter to check the accuracy

# %%
print("===================================================  \n")
print("kernel is liner")
svc_clf = SVC(kernel='linear')
svc_clf.fit(X_train, y_train)
svc_pred = svc_clf.predict(X_test)
print("confusion matrix is: ")
print(confusion_matrix(y_test,svc_pred))
print(classification_report(y_test,svc_pred))

print("=================================================== \n")

print("kernel is poly degree is 5")
svc_clf = SVC(kernel='poly', degree=5)
svc_clf.fit(X_train, y_train)
svc_pred_poly = svc_clf.predict(X_test)
print("confusion matrix is: ")
print(confusion_matrix(y_test,svc_pred_poly))
print(classification_report(y_test,svc_pred_poly))

print("===================================================  \n")

print("kernel is poly degree changed to 20")
svc_clf = SVC(kernel='poly', degree=20)
svc_clf.fit(X_train, y_train)
svc_pred_poly = svc_clf.predict(X_test)
print("confusion matrix is: ")
print(confusion_matrix(y_test,svc_pred_poly))
print(classification_report(y_test,svc_pred_poly))

print("===================================================  \n")

print("kernel is poly degree changed to 8")
svc_clf = SVC(kernel='poly', degree=8)
svc_clf.fit(X_train, y_train)
svc_pred_poly = svc_clf.predict(X_test)
print("confusion matrix is: ")
print(confusion_matrix(y_test,svc_pred_poly))
print(classification_report(y_test,svc_pred_poly))
print("===================================================")
print("kernel is rbf")
svc_clf = SVC(kernel='rbf')
svc_clf.fit(X_train, y_train)
svc_pred_gau = svc_clf.predict(X_test)
print(confusion_matrix(y_test,svc_pred_gau))
print(classification_report(y_test,svc_pred_gau))

print("===================================================")

print("kernel is sigmoid")
svc_clf = SVC(kernel='sigmoid')
svc_clf.fit(X_train, y_train)
svc_pred_sig = svc_clf.predict(X_test)
print(confusion_matrix(y_test,svc_pred_sig))
print(classification_report(y_test,svc_pred_sig))
# Out:
# ===================================================
#
# kernel is liner
# confusion matrix is:
# [[15  1]
#  [ 3 14]]
#               precision    recall  f1-score   support
#
#        False       0.83      0.94      0.88        16
#         True       0.93      0.82      0.87        17
#
#     accuracy                           0.88        33
#    macro avg       0.88      0.88      0.88        33
# weighted avg       0.88      0.88      0.88        33
#
# ===================================================
#
# kernel is poly degree is 5
# confusion matrix is:
# [[16  0]
#  [ 8  9]]
#               precision    recall  f1-score   support
#
#        False       0.67      1.00      0.80        16
#         True       1.00      0.53      0.69        17
#
#     accuracy                           0.76        33
#    macro avg       0.83      0.76      0.75        33
# weighted avg       0.84      0.76      0.74        33
#
# ===================================================
#
# kernel is poly degree changed to 20
# confusion matrix is:
# [[16  0]
#  [ 7 10]]
#               precision    recall  f1-score   support
#
#        False       0.70      1.00      0.82        16
#         True       1.00      0.59      0.74        17
#
#     accuracy                           0.79        33
#    macro avg       0.85      0.79      0.78        33
# weighted avg       0.85      0.79      0.78        33
#
# ===================================================
#
# kernel is poly degree changed to 8
# confusion matrix is:
# [[16  0]
#  [ 7 10]]
#               precision    recall  f1-score   support
#
#        False       0.70      1.00      0.82        16
#         True       1.00      0.59      0.74        17
#
#     accuracy                           0.79        33
#    macro avg       0.85      0.79      0.78        33
# weighted avg       0.85      0.79      0.78        33
#
# ===================================================
# kernel is rbf
# [[16  0]
#  [ 4 13]]
#               precision    recall  f1-score   support
#
#        False       0.80      1.00      0.89        16
#         True       1.00      0.76      0.87        17
#
#     accuracy                           0.88        33
#    macro avg       0.90      0.88      0.88        33
# weighted avg       0.90      0.88      0.88        33
#
# ===================================================
# kernel is sigmoid
# [[12  4]
#  [ 5 12]]
#               precision    recall  f1-score   support
#
#        False       0.71      0.75      0.73        16
#         True       0.75      0.71      0.73        17
#
#     accuracy                           0.73        33
#    macro avg       0.73      0.73      0.73        33
# weighted avg       0.73      0.73      0.73        33

# %% [markdown]
# # observation for SVC:
# For SVC when kernel Gaussian (rbf) we are getting maximum accuracy of 0.88

# %% [markdown]
# # 3) logistic regression
# Note: we have tried changing solver to liblinear and newton-cg to check accuracy

# %%
import sklearn.linear_model as skl_lm
log_clf = skl_lm.LogisticRegression(solver='newton-cg')
log_clf.fit(X_train,y_train)
log_pred = log_clf.predict(X_test)
log_pred_train = log_clf.predict(X_train)
accuracy_score(y_test, log_pred)
print(classification_report(y_test,log_pred, target_names = ['Not US','Is US'], digits = 7))
print("===================================================")
print("confusion matrix for y train is : ", confusion_matrix(y_train, log_pred_train))
print("confusion matrix for y test is : ", confusion_matrix(y_test, log_pred))
print("accuracy score for training : ", accuracy_score(y_train, log_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#       Not US  0.8333333 0.9375000 0.8823529        16
#        Is US  0.9333333 0.8235294 0.8750000        17
#
#     accuracy                      0.8787879        33
#    macro avg  0.8833333 0.8805147 0.8786765        33
# weighted avg  0.8848485 0.8787879 0.8785651        33
#
# ===================================================
# confusion matrix for y train is :  [[116  32]
#  [ 37 111]]
# confusion matrix for y test is :  [[15  1]
#  [ 3 14]]
# accuracy score for training :  0.7668918918918919

# %%
import sklearn.linear_model as skl_lm
log_clf = skl_lm.LogisticRegression(solver='liblinear')
log_clf.fit(X_train,y_train)
log_pred = log_clf.predict(X_test)
log_pred_train = log_clf.predict(X_train)
accuracy_score(y_test, log_pred)
print(classification_report(y_test,log_pred, target_names = ['Not US','Is US'], digits = 7))
print("===================================================")
print("confusion matrix for y train is : ", confusion_matrix(y_train, log_pred_train))
print("confusion matrix for y test is : ", confusion_matrix(y_test, log_pred))
print("accuracy score for training : ", accuracy_score(y_train, log_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#       Not US  0.8333333 0.9375000 0.8823529        16
#        Is US  0.9333333 0.8235294 0.8750000        17
#
#     accuracy                      0.8787879        33
#    macro avg  0.8833333 0.8805147 0.8786765        33
# weighted avg  0.8848485 0.8787879 0.8785651        33
#
# ===================================================
# confusion matrix for y train is :  [[118  30]
#  [ 37 111]]
# confusion matrix for y test is :  [[15  1]
#  [ 3 14]]
# accuracy score for training :  0.7736486486486487

# %% [markdown]
# # observation for logistic regression:
# For logistic regression, accuracy is 0.87 for both newton-cg and liblinear solvers.

# %% [markdown]
# # 4) LDA

# %%
lda_clf = LinearDiscriminantAnalysis(solver='svd')
lda_clf.fit(X_train,y_train)
lda_pred = lda_clf.predict(X_test)
accuracy_score(y_test, lda_pred)
lda_pred_train = lda_clf.predict(X_train)
print(classification_report(y_test,lda_pred, target_names = ['Not US','Is US'], digits = 7))
print("===================================================")
print("confusion matrix for y train is : \n", confusion_matrix(y_train, lda_pred_train))
print("confusion matrix for y test is : \n", confusion_matrix(y_test, lda_pred))
print("accuracy score for training : \n", accuracy_score(y_train, lda_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#       Not US  0.8333333 0.9375000 0.8823529        16
#        Is US  0.9333333 0.8235294 0.8750000        17
#
#     accuracy                      0.8787879        33
#    macro avg  0.8833333 0.8805147 0.8786765        33
# weighted avg  0.8848485 0.8787879 0.8785651        33
#
# ===================================================
# confusion matrix for y train is :
#  [[118  30]
#  [ 42 106]]
# confusion matrix for y test is :
#  [[15  1]
#  [ 3 14]]
# accuracy score for training :
#  0.7567567567567568

# %% [markdown]
# # obervation for LDA:
# for logistic when test data is reduced to 0.10 accuracy of this model is decreasing compared to to test data equal to 0.20
# Accuracy for LDA when test-to-train data split is 1:9 is 0.87

# %% [markdown]
# # 5) Decision tree

# %%
# ***** without tuning parameter *****
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train,y_train)
dt_pred = dt_clf.predict(X_test)
accuracy_score(y_test, dt_pred)
dt_pred_train = dt_clf.predict(X_train)
print(classification_report(y_test,dt_pred, target_names = ['Not US','Is US'], digits = 7))
print("===================================================")
print("confusion matrix for y train is : \n", confusion_matrix(y_train, dt_pred_train))
print("confusion matrix for y test is : \n", confusion_matrix(y_test, dt_pred))
print("accuracy score for training : \n", accuracy_score(y_train, dt_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#       Not US  0.8333333 0.9375000 0.8823529        16
#        Is US  0.9333333 0.8235294 0.8750000        17
#
#     accuracy                      0.8787879        33
#    macro avg  0.8833333 0.8805147 0.8786765        33
# weighted avg  0.8848485 0.8787879 0.8785651        33
#
# ===================================================
# confusion matrix for y train is :
#  [[148   0]
#  [  0 148]]
# confusion matrix for y test is :
#  [[15  1]
#  [ 3 14]]
# accuracy score for training :
#  1.0

# %% [markdown]
# # observation for decision tree
# when test data is equal to 0.10 accuracy of model is increasing to 0.9, when test data is equal to 0.20 accuracy of model is less, 0.77.
# Training accuracy is 1 so it is overfitting

# %%
# ****** with tuning parameter *******
for i in range (1, 10):
    print("Value of leaf: ", i)
    dt_clf = DecisionTreeClassifier(min_samples_leaf=i)
    dt_clf.fit(X_train,y_train)
    dt_pred = dt_clf.predict(X_test)
    accuracy_score(y_test, dt_pred)
    dt_pred_train = dt_clf.predict(X_train)
    print(classification_report(y_test,dt_pred, target_names = ['Not US','Is US'], digits = 7))
    print("===================================================")
    print("confusion matrix for y train is : \n", confusion_matrix(y_train, dt_pred_train))
    print("confusion matrix for y test is : \n", confusion_matrix(y_test, dt_pred))
    print("accuracy score for training : \n", accuracy_score(y_train, dt_pred_train))
    print("===================================================  \n")
# Out:
# Value of leaf:  1
#               precision    recall  f1-score   support
#
#       Not US  0.8333333 0.9375000 0.8823529        16
#        Is US  0.9333333 0.8235294 0.8750000        17
#
#     accuracy                      0.8787879        33
#    macro avg  0.8833333 0.8805147 0.8786765        33
# weighted avg  0.8848485 0.8787879 0.8785651        33
#
# ===================================================
# confusion matrix for y train is :
#  [[148   0]
#  [  0 148]]
# confusion matrix for y test is :
#  [[15  1]
#  [ 3 14]]
# accuracy score for training :
#  1.0
# ===================================================
#
# Value of leaf:  2
#               precision    recall  f1-score   support
#
#       Not US  0.8750000 0.8750000 0.8750000        16
#        Is US  0.8823529 0.8823529 0.8823529        17
#
#     accuracy                      0.8787879        33
#    macro avg  0.8786765 0.8786765 0.8786765        33
# weighted avg  0.8787879 0.8787879 0.8787879        33
#
# ===================================================
# confusion matrix for y train is :
#  [[145   3]
#  [  9 139]]
# confusion matrix for y test is :
#  [[14  2]
#  [ 2 15]]
# accuracy score for training :
#  0.9594594594594594
# ===================================================
#
# Value of leaf:  3
#               precision    recall  f1-score   support
#
#       Not US  0.9333333 0.8750000 0.9032258        16
#        Is US  0.8888889 0.9411765 0.9142857        17
#
#     accuracy                      0.9090909        33
#    macro avg  0.9111111 0.9080882 0.9087558        33
# weighted avg  0.9104377 0.9090909 0.9089233        33
#
# ===================================================
# confusion matrix for y train is :
#  [[144   4]
#  [ 13 135]]
# confusion matrix for y test is :
#  [[14  2]
#  [ 1 16]]
# accuracy score for training :
#  0.9425675675675675
# ===================================================
#
# Value of leaf:  4
#               precision    recall  f1-score   support
#
#       Not US  0.8571429 0.7500000 0.8000000        16
#        Is US  0.7894737 0.8823529 0.8333333        17
#
#     accuracy                      0.8181818        33
#    macro avg  0.8233083 0.8161765 0.8166667        33
# weighted avg  0.8222830 0.8181818 0.8171717        33
#
# ===================================================
# confusion matrix for y train is :
#  [[135  13]
#  [  9 139]]
# confusion matrix for y test is :
#  [[12  4]
#  [ 2 15]]
# accuracy score for training :
#  0.9256756756756757
# ===================================================
#
# Value of leaf:  5
#               precision    recall  f1-score   support
#
#       Not US  0.9230769 0.7500000 0.8275862        16
#        Is US  0.8000000 0.9411765 0.8648649        17
#
#     accuracy                      0.8484848        33
#    macro avg  0.8615385 0.8455882 0.8462255        33
# weighted avg  0.8596737 0.8484848 0.8467904        33
#
# ===================================================
# confusion matrix for y train is :
#  [[131  17]
#  [  6 142]]
# confusion matrix for y test is :
#  [[12  4]
#  [ 1 16]]
# accuracy score for training :
#  0.9222972972972973
# ===================================================
#
# Value of leaf:  6
#               precision    recall  f1-score   support
#
#       Not US  0.9375000 0.9375000 0.9375000        16
#        Is US  0.9411765 0.9411765 0.9411765        17
#
#     accuracy                      0.9393939        33
#    macro avg  0.9393382 0.9393382 0.9393382        33
# weighted avg  0.9393939 0.9393939 0.9393939        33
#
# ===================================================
# confusion matrix for y train is :
#  [[135  13]
#  [ 18 130]]
# confusion matrix for y test is :
#  [[15  1]
#  [ 1 16]]
# accuracy score for training :
#  0.8952702702702703
# ===================================================
#
# Value of leaf:  7
#               precision    recall  f1-score   support
#
#       Not US  0.9375000 0.9375000 0.9375000        16
#        Is US  0.9411765 0.9411765 0.9411765        17
#
#     accuracy                      0.9393939        33
#    macro avg  0.9393382 0.9393382 0.9393382        33
# weighted avg  0.9393939 0.9393939 0.9393939        33
#
# ===================================================
# confusion matrix for y train is :
#  [[133  15]
#  [ 18 130]]
# confusion matrix for y test is :
#  [[15  1]
#  [ 1 16]]
# accuracy score for training :
#  0.8885135135135135
# ===================================================
#
# Value of leaf:  8
#               precision    recall  f1-score   support
#
#       Not US  0.9333333 0.8750000 0.9032258        16
#        Is US  0.8888889 0.9411765 0.9142857        17
#
#     accuracy                      0.9090909        33
#    macro avg  0.9111111 0.9080882 0.9087558        33
# weighted avg  0.9104377 0.9090909 0.9089233        33
#
# ===================================================
# confusion matrix for y train is :
#  [[134  14]
#  [ 23 125]]
# confusion matrix for y test is :
#  [[14  2]
#  [ 1 16]]
# accuracy score for training :
#  0.875
# ===================================================
#
# Value of leaf:  9
#               precision    recall  f1-score   support
#
#       Not US  0.9333333 0.8750000 0.9032258        16
#        Is US  0.8888889 0.9411765 0.9142857        17
#
#     accuracy                      0.9090909        33
#    macro avg  0.9111111 0.9080882 0.9087558        33
# weighted avg  0.9104377 0.9090909 0.9089233        33
#
# ===================================================
# confusion matrix for y train is :
#  [[134  14]
#  [ 24 124]]
# confusion matrix for y test is :
#  [[14  2]
#  [ 1 16]]
# accuracy score for training :
#  0.8716216216216216
# ===================================================

# %% [markdown]
# # observation for decision tree
# we are getting best accuracy when number of leafs are equal to 7 i.e. of 0.93
# It is 0.86 when test-to-train data is split in 1:9 ratio and number of leafs = 6

# %% [markdown]
# # 6) svm.SVC

# %%
from sklearn.svm import SVC
print("===================================================  \n")
print("kernel is liner")
svc_clf = svm.SVC(kernel='linear')
svc_clf.fit(X_train, y_train)
svc_pred = svc_clf.predict(X_test)
print("confusion matrix is: ")
print(confusion_matrix(y_test,svc_pred))
print(classification_report(y_test,svc_pred))

print("=================================================== \n")

print("kernel is poly degree is 5")
svc_clf = svm.SVC(kernel='poly', degree=5)
svc_clf.fit(X_train, y_train)
svc_pred_poly = svc_clf.predict(X_test)
print("confusion matrix is: ")
print(confusion_matrix(y_test,svc_pred_poly))
print(classification_report(y_test,svc_pred_poly))

print("===================================================  \n")

print("kernel is poly degree changed to 20")
svc_clf = svm.SVC(kernel='poly', degree=20)
svc_clf.fit(X_train, y_train)
svc_pred_poly = svc_clf.predict(X_test)
print("confusion matrix is: ")
print(confusion_matrix(y_test,svc_pred_poly))
print(classification_report(y_test,svc_pred_poly))

print("===================================================  \n")

print("kernel is poly degree changed to 8")
svc_clf = svm.SVC(kernel='poly', degree=8)
svc_clf.fit(X_train, y_train)
svc_pred_poly = svc_clf.predict(X_test)
print("confusion matrix is: ")
print(confusion_matrix(y_test,svc_pred_poly))
print(classification_report(y_test,svc_pred_poly))
print("===================================================")
print("kernel is rbf")
svc_clf = svm.SVC(kernel='rbf')
svc_clf.fit(X_train, y_train)
svc_pred_gau = svc_clf.predict(X_test)
print(confusion_matrix(y_test,svc_pred_gau))
print(classification_report(y_test,svc_pred_gau))

print("===================================================")

print("kernel is sigmoid")
svc_clf = svm.SVC(kernel='sigmoid')
svc_clf.fit(X_train, y_train)
svc_pred_sig = svc_clf.predict(X_test)
print(confusion_matrix(y_test,svc_pred_sig))
print(classification_report(y_test,svc_pred_sig))
# Out:
# ===================================================
#
# kernel is liner
# confusion matrix is:
# [[15  1]
#  [ 3 14]]
#               precision    recall  f1-score   support
#
#        False       0.83      0.94      0.88        16
#         True       0.93      0.82      0.87        17
#
#     accuracy                           0.88        33
#    macro avg       0.88      0.88      0.88        33
# weighted avg       0.88      0.88      0.88        33
#
# ===================================================
#
# kernel is poly degree is 5
# confusion matrix is:
# [[16  0]
#  [ 8  9]]
#               precision    recall  f1-score   support
#
#        False       0.67      1.00      0.80        16
#         True       1.00      0.53      0.69        17
#
#     accuracy                           0.76        33
#    macro avg       0.83      0.76      0.75        33
# weighted avg       0.84      0.76      0.74        33
#
# ===================================================
#
# kernel is poly degree changed to 20
# confusion matrix is:
# [[16  0]
#  [ 7 10]]
#               precision    recall  f1-score   support
#
#        False       0.70      1.00      0.82        16
#         True       1.00      0.59      0.74        17
#
#     accuracy                           0.79        33
#    macro avg       0.85      0.79      0.78        33
# weighted avg       0.85      0.79      0.78        33
#
# ===================================================
#
# kernel is poly degree changed to 8
# confusion matrix is:
# [[16  0]
#  [ 7 10]]
#               precision    recall  f1-score   support
#
#        False       0.70      1.00      0.82        16
#         True       1.00      0.59      0.74        17
#
#     accuracy                           0.79        33
#    macro avg       0.85      0.79      0.78        33
# weighted avg       0.85      0.79      0.78        33
#
# ===================================================
# kernel is rbf
# [[16  0]
#  [ 4 13]]
#               precision    recall  f1-score   support
#
#        False       0.80      1.00      0.89        16
#         True       1.00      0.76      0.87        17
#
#     accuracy                           0.88        33
#    macro avg       0.90      0.88      0.88        33
# weighted avg       0.90      0.88      0.88        33
#
# ===================================================
# kernel is sigmoid
# [[12  4]
#  [ 5 12]]
#               precision    recall  f1-score   support
#
#        False       0.71      0.75      0.73        16
#         True       0.75      0.71      0.73        17
#
#     accuracy                           0.73        33
#    macro avg       0.73      0.73      0.73        33
# weighted avg       0.73      0.73      0.73        33

# %% [markdown]
# # SVM Observations -
# Best accuracy of 0.88 is observed with linear kernel and with Gaussian

# %% [markdown]
# # AOC - ROC

# %%
# logistic regression
model1 = LogisticRegression()
# knn
model2 = KNeighborsClassifier(n_neighbors=4)
# LDA
model3 = LinearDiscriminantAnalysis()
#SVM

model4 = svm.SVC(kernel='linear', probability = True)


#probas_ = classifier.fit(X_train, y_train).predict_proba(X_test)

# fit model
model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
model3.fit(X_train, y_train)
model4.fit(X_train, y_train)

# predict probabilities
pred_prob1 = model1.predict_proba(X_test)
pred_prob2 = model2.predict_proba(X_test)
pred_prob3 = model3.predict_proba(X_test)
pred_prob4 = model4.predict_proba(X_test)


from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob1[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob2[:,1], pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_test, pred_prob3[:,1], pos_label=1)
fpr4, tpr4, thresh4 = roc_curve(y_test, pred_prob4[:,1], pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, pred_prob1[:,1])
auc_score2 = roc_auc_score(y_test, pred_prob2[:,1])
auc_score3 = roc_auc_score(y_test, pred_prob3[:,1])
auc_score4 = roc_auc_score(y_test, pred_prob4[:,1])

print("AOC for Logistic Regression is :", auc_score1)
print("AOC for KNN is : ", auc_score2)
print("AOC for LDA is : ", auc_score3)
print("AOC for SVM is : ", auc_score4)

plt.style.use('seaborn')

# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='Logistic Regression')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='KNN')
plt.plot(fpr3, tpr3, linestyle='--',color='yellow', label='LDA')
plt.plot(fpr4, tpr4, linestyle='--',color='red', label='SVM')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();
# Out:
# AOC for Logistic Regression is : 0.9632352941176471
# AOC for KNN is :  0.9669117647058824
# AOC for LDA is :  0.9889705882352942
# AOC for SVM is :  0.9595588235294118

# %% [markdown]
# # Observation
# For test_data:train data = 1:9, AOC is highest for LDA with 0.98

# %% [markdown]
# # --- Cross validation ---

# %%
accent_dataset['isUS'] = [True if l == 'US' else False for l in accent_dataset['language']]
X_org = accent_dataset.drop(['language', 'isUS'], axis=1)
y_org = accent_dataset['isUS']
#print(X_org, y_org)

# %%
SEED =20

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=1)
#train_data, test_data, train_labels, test_labels = tts(predictors,target, test_size=test_size, stratify=target, random_state=SEED)
train_data, test_data, train_labels, test_labels = train_test_split(X_org, y_org, test_size=0.1, stratify=y, random_state=SEED)
train_data_20, test_data_20, train_labels_20, test_labels_20 = train_test_split(X_org, y_org, test_size=0.2, stratify=y, random_state=SEED)
train_data_33, test_data_33, train_labels_33, test_labels_33 = train_test_split(X_org, y_org, test_size=0.33, stratify=y, random_state=SEED)

pca_train, pca_test, pca_train_labels, pca_test_labels = train_test_split(X,y, test_size=0.1, stratify=y, random_state=SEED)
pca_train_20, pca_test_20, pca_train_labels_20, pca_test_labels_20 = train_test_split(X,y, test_size=0.2, stratify=y, random_state=SEED)
pca_train_33, pca_test_33, pca_train_labels_33, pca_test_labels_33 = train_test_split(X,y, test_size=0.33, stratify=y, random_state=SEED)

# %%
#range(start, stop, step)
knears_params = {"n_neighbors": list(range(1,10,1))}

log_reg_params = {
                  "penalty": ['l1', 'l2'], 
                  'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
                  "solver":['sag' ,'saga', 'liblinear','newton-cg', 'lbfgs'] 
                 }
svc_params = {
              'C': np.logspace(1, 3, 3), 
              'kernel': ['rbf', 'linear'],
              'gamma':np.logspace(-3, -1, 3)
             }

lda_params={'solver':['lsqr','eigen','svd']}

# %%
params = {
        '1':knears_params,
        '2':log_reg_params,
        '3':svc_params,
        '4':lda_params,
         }

# %%
#basline classifiers
classifiers = {
        "KNearest": KNeighborsClassifier(),       
        "LogisiticRegression": LogisticRegression(),
        "Support Vector Classifier": svm.SVC(probability=True),
        "LDA":LinearDiscriminantAnalysis(),
              }

# %%
datasets={
              'Org_10':[train_data,train_labels,test_data,test_labels],
              'Org_20':[train_data_20,train_labels_20,test_data_20,test_labels_20],
              'Org_33':[train_data_33,train_labels_33,test_data_33,test_labels_33],
              'PCA data set - 0.1':[pca_train,pca_train_labels,pca_test,pca_test_labels],
              'PCA data set - 0.2':[pca_train_20,pca_train_labels_20,pca_test_20,pca_test_labels_20],
              'PCA data set - 0.33':[pca_train_33,pca_train_labels_33,pca_test_33,pca_test_labels_33]
              
              
}

# %%
# cv parameters
from sklearn.model_selection import GridSearchCV, cross_val_score,KFold, StratifiedKFold

#to correcty compare results of the different datasets splits using the same random_state seed 

splits=10
cv_ = StratifiedKFold(n_splits=splits, random_state=SEED, shuffle=True)

# %%
def imbalanced_clf (cv=cv_, ds=datasets, clf=classifiers,par=params):
    df_results = pd.DataFrame()
    for key in ds:
        X_train=ds[key][0]
        y_train=ds[key][1]
        X_test=ds[key][2]
        y_test=ds[key][3]

        accuracy_lst = []
        precision_lst = []
        recall_lst = []
        f1_lst = []
        auc_lst = []
        
        for (key1,classifier),(key2,parameter) in zip(clf.items(),par.items()):
            #start_time = time.time()
            grid=GridSearchCV(classifier, parameter,cv=cv,scoring='f1_weighted')
            grid.fit(X_train, y_train)
            best_est = grid.best_estimator_
            prediction = best_est.predict(X_train)
            
            training_score = cross_val_score(best_est, X_train, y_train, scoring='f1_weighted',cv=cv)
            row = {
                'Dataset split': key,
                'model':classifier.__class__.__name__,
                #'run_time': format(round((time.time() - start_time)/60,2)),
                'F1 CV score': round(training_score.mean(), 2),
                'F1 score on test set': round(f1_score(y_test, best_est.predict(X_test), average='weighted'),4),
                'Precision score on test set': round(precision_score(y_test, best_est.predict(X_test), average='weighted'),4),
                'Recall score on test set': round(recall_score(y_test, best_est.predict(X_test), average='weighted'),4),
                'best parameters':grid.best_params_,
                   }
            df_results = df_results.append(row, ignore_index=True) 
    return df_results

# %%
imbalanced_clf()
# Out:
#           Dataset split                       model  F1 CV score  \
# 0                Org_10        KNeighborsClassifier         0.87
# 1                Org_10          LogisticRegression         0.77
# 2                Org_10                         SVC         0.88
# 3                Org_10  LinearDiscriminantAnalysis         0.71
# 4                Org_20        KNeighborsClassifier         0.86
# 5                Org_20          LogisticRegression         0.76
# 6                Org_20                         SVC         0.86
# 7                Org_20  LinearDiscriminantAnalysis         0.73
# 8                Org_33        KNeighborsClassifier         0.87
# 9                Org_33          LogisticRegression         0.73
# 10               Org_33                         SVC         0.85
# 11               Org_33  LinearDiscriminantAnalysis         0.70
# 12   PCA data set - 0.1        KNeighborsClassifier         0.85
# 13   PCA data set - 0.1          LogisticRegression         0.78
# 14   PCA data set - 0.1                         SVC         0.87
# 15   PCA data set - 0.1  LinearDiscriminantAnalysis         0.74
# 16   PCA data set - 0.2        KNeighborsClassifier         0.84
# 17   PCA data set - 0.2          LogisticRegression         0.77
# 18   PCA data set - 0.2                         SVC         0.85
# 19   PCA data set - 0.2  LinearDiscriminantAnalysis         0.71
# 20  PCA data set - 0.33        KNeighborsClassifier         0.86
# 21  PCA data set - 0.33          LogisticRegression         0.75
# 22  PCA data set - 0.33                         SVC         0.84
# 23  PCA data set - 0.33  LinearDiscriminantAnalysis         0.70
#
#     F1 score on test set  Precision score on test set  \
# 0                 0.7273                       0.7286
# 1                 0.8178                       0.8236
# 2                 0.7549                       0.7753
# 3                 0.7879                       0.7893
# 4                 0.7576                       0.7576
# 5                 0.7395                       0.7538
# 6                 0.7567                       0.7614
# 7                 0.7714                       0.7791
# 8                 0.8257                       0.8258
# 9                 0.7966                       0.8089
# 10                0.7798                       0.7803
# 11                0.7773                       0.7945
# 12                0.7268                       0.7276
# 13                0.8178                       0.8236
# 14                0.6667                       0.6679
# 15                0.7571                       0.7623
# 16                0.6800                       0.6861
# 17                0.7861                       0.7977
# 18                0.8008                       0.8173
# 19                0.7714                       0.7791
# 20                0.7337                       0.7345
# 21                0.8062                       0.8162
# 22                0.7504                       0.7590
# 23                0.7972                       0.8050
#
#     Recall score on test set  \
# 0                     0.7273
# 1                     0.8182
# 2                     0.7576
# 3                     0.7879
# 4                     0.7576
# 5                     0.7424
# 6                     0.7576
# 7                     0.7727
# 8                     0.8257
# 9                     0.7982
# 10                    0.7798
# 11                    0.7798
# 12                    0.7273
# 13                    0.8182
# 14                    0.6667
# 15                    0.7576
# 16                    0.6818
# 17                    0.7879
# 18                    0.8030
# 19                    0.7727
# 20                    0.7339
# 21                    0.8073
# 22                    0.7523
# 23                    0.7982
#
#                                       best parameters
# 0                                  {'n_neighbors': 3}
# 1   {'C': 0.1, 'penalty': 'l1', 'solver': 'libline...
# 2        {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 3                                  {'solver': 'lsqr'}
# 4                                  {'n_neighbors': 5}
# 5   {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 6        {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 7                                  {'solver': 'lsqr'}
# 8                                  {'n_neighbors': 3}
# 9   {'C': 0.1, 'penalty': 'l1', 'solver': 'libline...
# 10       {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 11                                 {'solver': 'lsqr'}
# 12                                 {'n_neighbors': 7}
# 13      {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# 14       {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 15                                 {'solver': 'lsqr'}
# 16                                 {'n_neighbors': 5}
# 17        {'C': 1, 'penalty': 'l2', 'solver': 'saga'}
# 18        {'C': 10.0, 'gamma': 0.01, 'kernel': 'rbf'}
# 19                                 {'solver': 'lsqr'}
# 20                                 {'n_neighbors': 5}
# 21      {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# 22         {'C': 10.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 23                                 {'solver': 'lsqr'}

# %% [markdown]
# # Observations
# KNN has the better F1-CV score
